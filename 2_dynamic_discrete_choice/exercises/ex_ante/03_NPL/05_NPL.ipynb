# %%
# magics: ensures that any changes to the modules loaded below will be re-loaded automatically
# %load_ext autoreload
# %autoreload 2

# load general packages
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8')

# load modules related to this exercise
import NPL_exante as NPL
from model_zucher_exante import zurcher
from Solve_NFXP import solve_NFXP
from estimate_NFXP import estimate as NFXP_estimate
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Problem set 5

# %% [markdown]
# #### 1. Look at the ReadMe.txt to get an overview of the code
#
# done

# %% [markdown]
# #### 2.What is the difference between $EV(x,a)$ and $V_{\sigma}(x)$?
#
# The difference between the two is that the EV is the expected value, whereas the $V_{\sigma} is the actual value. These shall therefore be compared to see how close the estimate is to the reality.

# %% [markdown]
# #### 3. Write the formula for $P=\Lambda(V_{\sigma})$, $V_{\sigma}=\psi(P)$ and $P=\Psi(P)$, exploiting the extreme value type I distribution on $\epsilon$.
# Hint: what is $e(a,P)\equiv E[\epsilon(a)|x,a]$ under this distributional assumption?
#
# Insert the found formulars under model_zucher_exante.psi ($V_{\sigma}=\psi(P)$) and model_zucher_exante.lambdaa ( $P=\Lambda(V_{\sigma})$)

# %% [markdown]
# #### 4. Solve the model using NPL, and plot the convergence of psi to check that your results are correct

# %%
# SETUP
model = zurcher()

# SOLVE THE MODEL
pk_NPL = NPL.solve(model)

fig = plt.figure(figsize=(10,4)) 
ax = fig.add_subplot(1,1,1)

ax.set_title(f'Convergence of $\Psi$')
ax.set_xlabel('Milage grid')
ax.set_ylabel('Replacement probability')
for i in range(5):
    ax.plot(model.grid,1-pk_NPL[i+1,:],color = 'red')
ax.plot(model.grid,1-pk_NPL[99,:],color = 'blue')
plt.show()

# %% [markdown]
# #### 5. Now you have to compare NFXP and NPL. Remeber that NFXP solve the fixed-point problem in value function space ( EV = Γ( EV ) ) and NPL solves it in CCP space ( pk = Ψ( pk ) ). Calculate the CCPs from either method and compare the results

# %%
# solve the model with NFXP
ev0 = np.zeros(model.n)
solver_NFXP = solve_NFXP()
_, pk_NFXP = solver_NFXP.poly(model.bellman, ev0, beta=model.beta, output=2)


# Define figure
fig = plt.figure(figsize=(10,4)) 
ax = fig.add_subplot(1,1,1)



ax.plot(model.grid,1-pk_NPL[6,:],label=f'Replacement probability at K = 6')
ax.plot(model.grid,1-pk_NPL[99,:],label=f'Last evaluation of $\Psi$')
ax.plot(model.grid,1-pk_NFXP,label=f'Fixed point of $\Gamma$ (NFXP)')

ax.set_xlabel('Milage grid')
ax.set_ylabel('Replacement probability')
plt.legend()

plt.show()

# %% [markdown]
# #### 6. $F^{U}(pk)$ is the unconditional transition probabilities induced by pk (vector) - what does that mean?
# (a) Try changing the number of gridpoints to 5 and the transition probability vector to a scalar of 0.65, place a debugger (alternatively print statement) in the model_zucher_exante.psi.py-function and compare Fu and P1. What is the difference between the two?

# %% [markdown]
# #### 7. What determines if NFXP is computationally cheaper to use than NPL? Think about what is in the inner loop of either algorithm.

# %% [markdown]
# #### 8. Now we have to Estimate the model using NPL. In order to estimate the model you should understand
# <il type ="a">
# <li> NPL.estimate </li>
# <li> NPL.ll (skip the part of computing the gradient and the Hessian)</li>
# </il>

# %% [markdown]
# #### 7. Fill in the missing stuff in NPL.ll, and run the code below to check that your results are correct

# %%
 # ESTIMATE
# setup
Kmax=10  # Max number of outer loop iterations for NPL 
pnames = ['RC','c']
model = zurcher()

# Load data
data = model.read_busdata(bustypes=[1,2,3,4])
data_class = NPL.setup_data(data)
samplesize = data_class.x.size

#Estimate using NPL
import time
t0 = time.time()
res, theta_hat,pk = NPL.estimate(model, data_class, Kmax)
t1 = time.time()

# Print the results
print(f'Structual estimation using busdata from Rust(1987)')
print(f'Beta        = {model.beta:.4f}')
print(f'n           = {model.n}')
print(f'Sample size = {samplesize}')

print('\n \nNPL \n--------------------------------')
print(f'Parameters     Estimates    s.e. ') 
print(f'{pnames[0]}             {theta_hat[0]:.4f}     ')
print(f'{pnames[1]}              {theta_hat[1]:.4f}      \n ')


print(f'Log-likelihood {-res.fun*samplesize:.4f}') 
print(f'runtime (seconds) {(t1-t0):.4f}')

# Estimate using NFXP
theta0 = (0.,0.)
solver_NFXP = solve_NFXP()
t0 = time.time()
nfxp_model, optim_res, pnames, theta_hat, Avar, converged=NFXP_estimate(model, solver_NFXP,data,theta0=theta0, twostep=0)

t1 = time.time()
time = t1-t0

# Print the result
print('\n \nNFXP \n--------------------------------')
print(f'Parameters     Estimates    s.e. ') 
print(f'{pnames[0]}             {theta_hat[0]:.4f}     {np.sqrt(Avar[0,0]):.4f} ')
print(f'{pnames[1]}              {theta_hat[1]:.4f}     {np.sqrt(Avar[1,1]):.4f} \n ')

print(f'Log-likelihood {-optim_res.fun*samplesize:.2f}') 
print(f'runtime (seconds) {time:.4f}')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 15
#      13 import time
#      14 t0 = time.time()
# ---> 15 res, theta_hat,pk = NPL.estimate(model, data_class, Kmax)
#      16 t1 = time.time()
#      18 # Print the results
#
# File c:\Users\PC\OneDrive\Skrivebord\dynamic\Dynamic-programming\2_dynamic_discrete_choice\exercises\ex_ante\03_NPL\NPL_exante.py:44, in estimate(model, data, Kmax)
#      40 model.unc_state_transition(pk0) # Calculate Fu and Finv
#      42 #Inner loop:
#      43 # Step 1)  Maximize the pseudo-likelihood function given step K-1 CCPs
# ---> 44 res = optimize.minimize(ll,theta0,args =(model, data, pk0), method='Newton-CG', jac = grad, hess= hes, tol = 1e-6)
#      45 theta_hat = res.x # save parameters
#      46 NPL_metric = np.abs(theta0-theta_hat) #save distance between parameters
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\optimize\_minimize.py:710, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     708     res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#     709 elif meth == 'newton-cg':
# --> 710     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     711                              **options)
#     712 elif meth == 'l-bfgs-b':
#     713     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     714                            callback=callback, **options)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\optimize\_optimize.py:2097, in _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback, xtol, eps, maxiter, disp, return_all, c1, c2, **unknown_options)
#    2095 x0 = asarray(x0).flatten()
#    2096 # TODO: add hessp (callable or FD) to ScalarFunction?
# -> 2097 sf = _prepare_scalar_function(
#    2098     fun, x0, jac, args=args, epsilon=eps, hess=hess
#    2099 )
#    2100 f = sf.fun
#    2101 fprime = sf.grad
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\optimize\_optimize.py:402, in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     398     bounds = (-np.inf, np.inf)
#     400 # ScalarFunction caches. Reuse of fun(x) during grad
#     401 # calculation reduces overall function evaluations.
# --> 402 sf = ScalarFunction(fun, x0, args, grad, hess,
#     403                     finite_diff_rel_step, bounds, epsilon=epsilon)
#     405 return sf
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\optimize\_differentiable_functions.py:166, in ScalarFunction.__init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#     163     self.f = fun_wrapped(self.x)
#     165 self._update_fun_impl = update_fun
# --> 166 self._update_fun()
#     168 # Gradient evaluation
#     169 if callable(grad):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\optimize\_differentiable_functions.py:262, in ScalarFunction._update_fun(self)
#     260 def _update_fun(self):
#     261     if not self.f_updated:
# --> 262         self._update_fun_impl()
#     263         self.f_updated = True
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\optimize\_differentiable_functions.py:163, in ScalarFunction.__init__.<locals>.update_fun()
#     162 def update_fun():
# --> 163     self.f = fun_wrapped(self.x)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\optimize\_differentiable_functions.py:145, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     141 self.nfev += 1
#     142 # Send a copy because the user may overwrite it.
#     143 # Overwriting results in undefined behaviour because
#     144 # fun(self.x) will change self.x, with the two no longer linked.
# --> 145 fx = fun(np.copy(x), *args)
#     146 # Make sure the function returns a true scalar
#     147 if not np.isscalar(fx):
#
# File c:\Users\PC\OneDrive\Skrivebord\dynamic\Dynamic-programming\2_dynamic_discrete_choice\exercises\ex_ante\03_NPL\NPL_exante.py:74, in ll(theta, model, data, pk0, out)
#      67 model.create_grid()
#      69 # Update CCPs
#      70 #Fill in
#      71 #pk =
#      72
#      73 #Map choice probabilities to data
# ---> 74 pKdata = pk[data.x]
#      76 #Return CCPs if out = 2
#      77 if out == 2:
#
# TypeError: 'float' object is not subscriptable
